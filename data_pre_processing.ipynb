# %%
import pymongo

connection_string = "mongodb+srv://praks8870:Prakash9.@praksdb.obppr2u.mongodb.net/?retryWrites=true&w=majority"

client = pymongo.MongoClient(connection_string)
db = client['sample_airbnb']
mycol = db['listingsAndReviews']

# %%
new_data = []
for i in mycol.find():
    data = dict(id = i['_id'],
                listing_url = i['listing_url'],
                name = i.get('name'),
                description = i['description'],
                house_rules = i['house_rules'],
                property_type = i['property_type'],
                room_type = i['room_type'],
                bed_type =i['bed_type'],
                min_nights = i['minimum_nights'],
                max_nights = i['maximum_nights'],
                cancellation = i['cancellation_policy'],
                last_scraped = i['last_scraped'],
                last_review = i.get('last_review'),
                accomodates = i['accommodates'],
                bedrooms = i.get('bedrooms'),
                beds = i.get('beds'),
                review_count = i['number_of_reviews'],
                bathrooms  = i.get('bathrooms'),
                amenities = ', '.join(i['amenities']),
                security_deposit = i.get('security_deposit'),
                cleaning_fee = i.get('cleaning_fee'),
                extra_people = i['extra_people'],
                guests = i['guests_included'],
                image = i['images']['picture_url'],
                host = i['host']['host_id'],
                host_name = i['host']['host_name'],
                host_response_rate = i['host'].get('host_response_rate'),
                listings = i['host']['host_total_listings_count'],
                street = i['address']['street'],
                country = i['address']['country'],
                country_code = i['address']['country_code'],
                location_type = i['address']['location']['type'],
                longitude = i['address']['location']['coordinates'][0],
                latitude = i['address']['location']['coordinates'][1],
                location_exact = i['address']['location']['is_location_exact'],
                availability_30 = i['availability']['availability_30'],
                availability_60 = i['availability']['availability_60'],
                availability_90 = i['availability']['availability_90'],
                availability_365 = i['availability']['availability_365'],
                review_rating_score = i['review_scores'].get('review_scores_rating'),
                price = i['price']
                )
    
    new_data.append(data)

# %%
import pandas as pd

df = pd.DataFrame(new_data)

df
# Out:
#             id                            listing_url  \
# 0     10006546  https://www.airbnb.com/rooms/10006546
# 1     10009999  https://www.airbnb.com/rooms/10009999
# 2      1001265   https://www.airbnb.com/rooms/1001265
# 3     10021707  https://www.airbnb.com/rooms/10021707
# 4     10030955  https://www.airbnb.com/rooms/10030955
# ...        ...                                    ...
# 5550   9983221   https://www.airbnb.com/rooms/9983221
# 5551   9985696   https://www.airbnb.com/rooms/9985696
# 5552   9987200   https://www.airbnb.com/rooms/9987200
# 5553   9990304   https://www.airbnb.com/rooms/9990304
# 5554   9993190   https://www.airbnb.com/rooms/9993190
#
#                                                    name  \
# 0                               Ribeira Charming Duplex
# 1                          Horto flat with small garden
# 2                      Ocean View Waikiki Marina w/prkg
# 3                              Private Room in Bushwick
# 4                           Apt Linda Vista Lagoa - Rio
# ...                                                 ...
# 5550                      Cozy apartment downtown Porto
# 5551                                    Kadıköy-Altıyol
# 5552       The best suite in Copacabana (total privacy)
# 5553     March Madness Special! Aina Nalu Platinum D107
# 5554  Just Steps from the Ocean at Premier Platinum ...
#
#                                             description  \
# 0     Fantastic duplex apartment with three bedrooms...
# 1     One bedroom + sofa-bed in quiet and bucolic ne...
# 2     A short distance from Honolulu's billion dolla...
# 3     Here exists a very cozy room for rent in a sha...
# 4     Quarto com vista para a Lagoa Rodrigo de Freit...
# ...                                                 ...
# 5550  Renovated, fully equipped, within walking dist...
# 5551  Kadıköy merkezde 2+1 dairem vardır.Çok kalabal...
# 5552  Excellent private suite with bathroom at the A...
# 5553  Walk out to Saltwater Infinity Pool! Call us N...
# 5554  Relax Hawaiian Style in Gated Community on Oce...
#
#                                             house_rules property_type  \
# 0                           Make the house your home...         House
# 1     I just hope the guests treat the space as they...     Apartment
# 2     The general welfare and well being of all the ...   Condominium
# 3                                                           Apartment
# 4                                                           Apartment
# ...                                                 ...           ...
# 5550  Non smoking.  The hosts are supposed to leave ...     Apartment
# 5551                                                            House
# 5552                            Checked-in guests only.    Aparthotel
# 5553  As a guest of Coconut Condos, I agree to the f...   Condominium
# 5554  As a guest of Coconut Condos, I agree to the f...     Townhouse
#
#             room_type  bed_type min_nights max_nights  ... location_type  \
# 0     Entire home/apt  Real Bed          2         30  ...         Point
# 1     Entire home/apt  Real Bed          2       1125  ...         Point
# 2     Entire home/apt  Real Bed          3        365  ...         Point
# 3        Private room  Real Bed         14       1125  ...         Point
# 4        Private room  Real Bed          1       1125  ...         Point
# ...               ...       ...        ...        ...  ...           ...
# 5550  Entire home/apt  Real Bed          3       1125  ...         Point
# 5551  Entire home/apt  Real Bed          1       1125  ...         Point
# 5552     Private room  Real Bed          3         60  ...         Point
# 5553  Entire home/apt  Real Bed          3        365  ...         Point
# 5554  Entire home/apt  Real Bed          3        365  ...         Point
#
#        longitude   latitude  location_exact  availability_30  availability_60  \
# 0      -8.613080  41.141300           False               28               47
# 1     -43.230750 -22.966254            True                0                0
# 2    -157.839190  21.286340            True               16               46
# 3     -73.936150  40.697910            True                0                0
# 4     -43.205047 -22.971951            True               28               58
# ...          ...        ...             ...              ...              ...
# 5550   -8.616930  41.151370           False               26               51
# 5551   29.030790  40.985630           False               30               60
# 5552  -43.176533 -22.961076            True                7               29
# 5553 -156.676460  20.875610           False                8               20
# 5554 -156.667520  20.858940           False                0                8
#
#       availability_90 availability_365 review_rating_score   price
# 0                  74              239                89.0   80.00
# 1                   0                0                 NaN  317.00
# 2                  76              343                84.0  115.00
# 3                   0                0               100.0   40.00
# 4                  88              363                 NaN  701.00
# ...               ...              ...                 ...     ...
# 5550               77              300                98.0   58.00
# 5551               90              365                 NaN  501.00
# 5552               53               53                97.0  101.00
# 5553               26              243                97.0  227.00
# 5554               31              258                92.0  220.00
#
# [5555 rows x 41 columns]

# %%
df.isnull().sum()
# Out:
# id                        0
# listing_url               0
# name                      0
# description               0
# house_rules               0
# property_type             0
# room_type                 0
# bed_type                  0
# min_nights                0
# max_nights                0
# cancellation              0
# last_scraped              0
# last_review            1388
# accomodates               0
# bedrooms                  5
# beds                     13
# review_count              0
# bathrooms                10
# amenities                 0
# security_deposit       2084
# cleaning_fee           1531
# extra_people              0
# guests                    0
# image                     0
# host                      0
# host_name                 0
# host_response_rate     1388
# listings                  0
# street                    0
# country                   0
# country_code              0
# location_type             0
# longitude                 0
# latitude                  0
# location_exact            0
# availability_30           0
# availability_60           0
# availability_90           0
# availability_365          0
# review_rating_score    1474
# price                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 41 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   5555 non-null   object
#  1   listing_url          5555 non-null   object
#  2   name                 5555 non-null   object
#  3   description          5555 non-null   object
#  4   house_rules          5555 non-null   object
#  5   property_type        5555 non-null   object
#  6   room_type            5555 non-null   object
#  7   bed_type             5555 non-null   object
#  8   min_nights           5555 non-null   object
#  9   max_nights           5555 non-null   object
#  10  cancellation         5555 non-null   object
#  11  last_scraped         5555 non-null   datetime64[ns]
#  12  last_review          4167 non-null   datetime64[ns]
#  13  accomodates          5555 non-null   int64
#  14  bedrooms             5550 non-null   float64
#  15  beds                 5542 non-null   float64
#  16  review_count         5555 non-null   int64
#  17  bathrooms            5545 non-null   object
#  18  amenities            5555 non-null   object
#  19  security_deposit     3471 non-null   object
#  20  cleaning_fee         4024 non-null   object
#  21  extra_people         5555 non-null   object
#  22  guests               5555 non-null   object
#  23  image                5555 non-null   object
#  24  host                 5555 non-null   object
#  25  host_name            5555 non-null   object
#  26  host_response_rate   4167 non-null   float64
#  27  listings             5555 non-null   int64
#  28  street               5555 non-null   object
#  29  country              5555 non-null   object
#  30  country_code         5555 non-null   object
#  31  location_type        5555 non-null   object
#  32  longitude            5555 non-null   float64
#  33  latitude             5555 non-null   float64
#  34  location_exact       5555 non-null   bool
#  35  availability_30      5555 non-null   int64
#  36  availability_60      5555 non-null   int64
#  37  availability_90      5555 non-null   int64
#  38  availability_365     5555 non-null   int64
#  39  review_rating_score  4081 non-null   float64
#  40  price                5555 non-null   object
# dtypes: bool(1), datetime64[ns](2), float64(6), int64(7), object(25)
# memory usage: 1.7+ MB

# %%
df.security_deposit = df.security_deposit[~df.security_deposit.isna()].astype(str).astype(float)
df.min_nights = df.min_nights.astype(str).astype(float)
df.max_nights = df.max_nights.astype(str).astype(float)
df.price = df.price.astype(str).astype(float)
df.cleaning_fee = df.cleaning_fee[~df.cleaning_fee.isna()].astype(str).astype(float)
df.extra_people = df.extra_people.astype(str).astype(float)
df.guests = df.guests.astype(str).astype(float)

# %%
df.isnull().sum()
# Out:
# id                        0
# listing_url               0
# name                      0
# description               0
# house_rules               0
# property_type             0
# room_type                 0
# bed_type                  0
# min_nights                0
# max_nights                0
# cancellation              0
# last_scraped              0
# last_review            1388
# accomodates               0
# bedrooms                  5
# beds                     13
# review_count              0
# bathrooms                10
# amenities                 0
# security_deposit       2084
# cleaning_fee           1531
# extra_people              0
# guests                    0
# image                     0
# host                      0
# host_name                 0
# host_response_rate     1388
# listings                  0
# street                    0
# country                   0
# country_code              0
# location_type             0
# longitude                 0
# latitude                  0
# location_exact            0
# availability_30           0
# availability_60           0
# availability_90           0
# availability_365          0
# review_rating_score    1474
# price                     0
# dtype: int64

# %%
df.bedrooms.fillna(df.bedrooms.mode()[0], inplace = True)
df.beds.fillna(df.beds.median(), inplace= True)
df.security_deposit.fillna(df.security_deposit.median(), inplace= True)
df.min_nights.fillna(df.min_nights.median(), inplace= True)
df.cleaning_fee.fillna(df.cleaning_fee.median(), inplace= True)
df.host_response_rate.fillna(df.host_response_rate.median(), inplace= True)
df.review_rating_score.fillna(df.review_rating_score.median(), inplace= True)
df.bathrooms.fillna('', inplace= True)
df.last_review.fillna(0, inplace= True)
df.last_review.replace(to_replace= 0, value = 'No Reviews', inplace= True)
df.description.replace(to_replace= '', value = 'No description provided', inplace= True)
df.house_rules.replace(to_replace= '', value= 'No details', inplace= True)
df['location_exact'] = df['location_exact'].replace({True: 'yes', False: 'no'})
df['max_nights'] = df.max_nights.astype(float).astype(int)
# Out:
# C:\Users\PRAKASH\AppData\Local\Temp\ipykernel_6904\3417467849.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   df.last_review.fillna(0, inplace= True)

# %%
df.isnull().sum()
# Out:
# id                     0
# listing_url            0
# name                   0
# description            0
# house_rules            0
# property_type          0
# room_type              0
# bed_type               0
# min_nights             0
# max_nights             0
# cancellation           0
# last_scraped           0
# last_review            0
# accomodates            0
# bedrooms               0
# beds                   0
# review_count           0
# bathrooms              0
# amenities              0
# security_deposit       0
# cleaning_fee           0
# extra_people           0
# guests                 0
# image                  0
# host                   0
# host_name              0
# host_response_rate     0
# listings               0
# street                 0
# country                0
# country_code           0
# location_type          0
# longitude              0
# latitude               0
# location_exact         0
# availability_30        0
# availability_60        0
# availability_90        0
# availability_365       0
# review_rating_score    0
# price                  0
# dtype: int64

# %%
df.describe().T
# Out:
#                       count                           mean  \
# min_nights           5555.0                       5.564356
# max_nights           5555.0                 1382776.320072
# last_scraped           5555  2019-03-01 12:48:43.420342016
# accomodates          5555.0                       3.505851
# bedrooms             5555.0                       1.411341
# beds                 5555.0                       2.071287
# review_count         5555.0                      27.606481
# security_deposit     5555.0                     393.345275
# cleaning_fee         5555.0                      84.683528
# extra_people         5555.0                      22.791899
# guests               5555.0                       1.747435
# host_response_rate   5555.0                      94.837804
# longitude            5555.0                       -6.62324
# latitude             5555.0                       22.06123
# availability_30      5555.0                      11.816202
# availability_60      5555.0                      26.451305
# availability_90      5555.0                      42.758056
# availability_365     5555.0                     173.105671
# review_rating_score  5555.0                        93.6036
# price                5555.0                     278.766157
#
#                                      min                  25%  \
# min_nights                           1.0                  1.0
# max_nights                           1.0                 59.0
# last_scraped         2019-02-11 05:00:00  2019-02-18 05:00:00
# accomodates                          1.0                  2.0
# bedrooms                             0.0                  1.0
# beds                                 0.0                  1.0
# review_count                         0.0                  1.0
# security_deposit                     0.0                100.0
# cleaning_fee                         0.0                 35.0
# extra_people                         0.0                  0.0
# guests                               1.0                  1.0
# host_response_rate                   0.0                100.0
# longitude                     -159.67869            -73.59953
# latitude                       -34.08829             20.72439
# availability_30                      0.0                  0.0
# availability_60                      0.0                  0.0
# availability_90                      0.0                  0.0
# availability_365                     0.0                 17.0
# review_rating_score                 20.0                 93.0
# price                                9.0                 70.0
#
#                                      50%                  75%  \
# min_nights                           2.0                  3.0
# max_nights                        1125.0               1125.0
# last_scraped         2019-03-07 05:00:00  2019-03-08 05:00:00
# accomodates                          3.0                  4.0
# bedrooms                             1.0                  2.0
# beds                                 2.0                  3.0
# review_count                         5.0                 32.0
# security_deposit                   200.0                250.0
# cleaning_fee                        60.0                100.0
# extra_people                         0.0                 20.0
# guests                               1.0                  2.0
# host_response_rate                 100.0                100.0
# longitude                       -8.61142            29.019605
# latitude                        40.72713            41.162755
# availability_30                      8.0                 24.0
# availability_60                     23.0                 52.0
# availability_90                     43.0                 80.0
# availability_365                   171.0                317.0
# review_rating_score                 95.0                 98.0
# price                              129.0                280.0
#
#                                      max              std
# min_nights                        1250.0        22.613861
# max_nights                  2147483647.0  52569200.038017
# last_scraped         2019-03-11 04:00:00              NaN
# accomodates                         16.0         2.297019
# bedrooms                            20.0         1.041547
# beds                                25.0         1.617767
# review_count                       533.0        49.798376
# security_deposit                 39228.0      1269.450131
# cleaning_fee                      2000.0        95.020542
# extra_people                      2346.0        69.331511
# guests                              16.0         1.487352
# host_response_rate                 100.0        16.332468
# longitude                      151.33898        90.525974
# latitude                        45.66563        28.092112
# availability_30                     30.0        11.686113
# availability_60                     60.0        23.476011
# availability_90                     90.0        35.226897
# availability_365                   365.0       139.841893
# review_rating_score                100.0         7.779357
# price                            48842.0       842.215531

# %%
import matplotlib.pyplot as plt
import seaborn as sns

n_cols = df.select_dtypes(include= ['int64', 'float64', 'int32', 'float32']).columns
n_cols = n_cols[n_cols != 'price']

num_cols = len(n_cols)
num_rows = (num_cols // 3) + (num_cols % 3 > 0)

fig, axes = plt.subplots(nrows = num_rows, ncols = 3, figsize =  (15, num_rows * 5))

axes = axes.flatten()

for i, col in enumerate(n_cols):
    axes[i].scatter(df[col], df['price'], alpha=0.5)
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('price')


plt.tight_layout()

plt.show()

# %%
df.head()
# Out:
#          id                            listing_url  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1  10009999  https://www.airbnb.com/rooms/10009999
# 2   1001265   https://www.airbnb.com/rooms/1001265
# 3  10021707  https://www.airbnb.com/rooms/10021707
# 4  10030955  https://www.airbnb.com/rooms/10030955
#
#                                name  \
# 0           Ribeira Charming Duplex
# 1      Horto flat with small garden
# 2  Ocean View Waikiki Marina w/prkg
# 3          Private Room in Bushwick
# 4       Apt Linda Vista Lagoa - Rio
#
#                                          description  \
# 0  Fantastic duplex apartment with three bedrooms...
# 1  One bedroom + sofa-bed in quiet and bucolic ne...
# 2  A short distance from Honolulu's billion dolla...
# 3  Here exists a very cozy room for rent in a sha...
# 4  Quarto com vista para a Lagoa Rodrigo de Freit...
#
#                                          house_rules property_type  \
# 0                        Make the house your home...         House
# 1  I just hope the guests treat the space as they...     Apartment
# 2  The general welfare and well being of all the ...   Condominium
# 3                                         No details     Apartment
# 4                                         No details     Apartment
#
#          room_type  bed_type  min_nights  max_nights  ... location_type  \
# 0  Entire home/apt  Real Bed         2.0          30  ...         Point
# 1  Entire home/apt  Real Bed         2.0        1125  ...         Point
# 2  Entire home/apt  Real Bed         3.0         365  ...         Point
# 3     Private room  Real Bed        14.0        1125  ...         Point
# 4     Private room  Real Bed         1.0        1125  ...         Point
#
#     longitude   latitude  location_exact  availability_30  availability_60  \
# 0   -8.613080  41.141300              no               28               47
# 1  -43.230750 -22.966254             yes                0                0
# 2 -157.839190  21.286340             yes               16               46
# 3  -73.936150  40.697910             yes                0                0
# 4  -43.205047 -22.971951             yes               28               58
#
#    availability_90 availability_365 review_rating_score  price
# 0               74              239                89.0   80.0
# 1                0                0                95.0  317.0
# 2               76              343                84.0  115.0
# 3                0                0               100.0   40.0
# 4               88              363                95.0  701.0
#
# [5 rows x 41 columns]

# %%
df

# %%
from scipy import stats

z_scores = stats.zscore(df['price'])

threshold = 3

outliers = df[abs(z_scores) > threshold]
df1 = df[abs(z_scores) <= threshold]

df1

# %%
df.to_csv('D:\\airbnb_project\\airbnb.csv', index=False, header=True, encoding='utf-8')

# %%
df_c = df['listings'].unique()
print(df_c)
# Out:
# [   3    1   18    2    5   13    6    8   16   29  472    4    7   17
#    10    9   28   12   65   22  109   46   24   95   92  294   20   15
#    35   23   14   85   30   59   66   34   74   31   45   98   11   38
#   156   19   40   80 1198   26  104   47  158   37   60   67   41  799
#    70    0   53  152   51  106   33  102   42  130  120   21  121   63
#    32   90   61   36   87   44  226   49  508   77   50  203  183   86
#   429   73   71   43   48   82  222   58   68  320   57  101  116  160
#   256   54  100  126  187  111   55  169   25  177   39  200   52   56
#    62   69  113  128  229  324  164   64  265  115  241   27  170  117
#   105  155  239  372  103  153]

# %%
import matplotlib.pyplot as plt

# Assuming 'host' is the column containing host information and 'listings' is the column with the number of listings
top_hosts = df['host'].value_counts().head(10).index.tolist()
result_df = df[df['host'].isin(top_hosts)]

df3 = df.sort_values(by='listings', ascending=False)

# plt.figure(figsize=(10, 6))
# plt.bar(result_df['host_name'], result_df['listings'] )
# plt.xlabel('Hosts')
# plt.ylabel('Number of Listings')
# plt.title('Top 10 Hosts and Their Listings')
# plt.xticks(rotation=45, ha='right')  
# plt.show()

df4 = df3[['host', 'host_name', 'listings']].drop_duplicates()
df4.head(10)
# Out:
#            host                   host_name  listings
# 5173   12243051                      Sonder      1198
# 687    30283594                        Kara       799
# 1405  102947901                     Claudia       508
# 48     12057949                       Holly       472
# 5154    3953109             Feels Like Home       429
# 4055  156331964               Grand Welcome       372
# 2908  137500257                        Loic       324
# 1910   91654021                      Daniel       320
# 201     2154262  Condominium Rentals Hawaii       294
# 2194   36410227                     Sabrina       294

# %%
df_p = df['property_type'].value_counts().head(10)
df_p.columns = ['property_type', 'count']
df_p
# Out:
# property_type
# Apartment             3626
# House                  606
# Condominium            399
# Serviced apartment     185
# Loft                   142
# Townhouse              108
# Guest suite             81
# Bed and breakfast       69
# Boutique hotel          53
# Guesthouse              50
# Name: count, dtype: int64
